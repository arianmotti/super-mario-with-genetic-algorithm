# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# used for visualization
# cells with highter cost will be darker
def shadeColor(color, percent) :

    R = int(color[1:3], 16)
    G = int(color[3:5], 16)
    B = int(color[5:7], 16)

    R = int(R * (100 + percent) / 100)
    G = int(G * (100 + percent) / 100)
    B = int(B * (100 + percent) / 100)

    R = R if R < 255 else 255
    G = G if G < 255 else 255
    B = B if B < 255 else 255

    RR = "0" + hex(R)[2:] if len(hex(R)[2:]) == 1 else hex(R)[2:]
    GG = "0" + hex(G)[2:] if len(hex(G)[2:]) == 1 else hex(G)[2:]
    BB = "0" + hex(B)[2:] if len(hex(B)[2:]) == 1 else hex(B)[2:]
    return "#"+RR+GG+BB

# getting input map file and making "config" object filled with necessary informations


ground_y = 1
goomba_y = 1
mushroom_y = 1
lakitu_y = 2
top_y = 3


def setup_map_config(file_name):
    
    file = open(file_name)
    line = file.readline()
    header = line.strip()
    
    goomba = []

    ground   = [i for i, x in enumerate(line) if x == "_"] # y = 1
    goomba   = [i for i, x in enumerate(line) if x == "G"] # y = 1
    mushroom = [i for i, x in enumerate(line) if x == "M"] # y = 1
    lakitu   = [i for i, x in enumerate(line) if x == "L"] # y = 2
    luigi    = [(0, ground_y), (0, ground_y + 1)]
    
    sky = []
    for i in range(len(line) + 1):
            sky.append((i, ground_y))
            sky.append((i, lakitu_y))
            sky.append((i, top_y))
            

    return {
        'original' : line,
        'ground'   : ground,
        'goomba'   : goomba,
        'lakitu'   : lakitu, 
        'mushroom' : mushroom,
        'sky'      : sky,
        'luigi'    : luigi,
    }

# visualizer
def draw_config(config, save=False, path=None ,file_name=None, show=True, dpi=100):
    
    original = config['original']
    ground   = config['ground']
    goomba   = config['goomba']
    lakitu   = config['lakitu']
    mushroom = config['mushroom']
    sky      = config['sky']
    luigi    = config['luigi']
    
    map_size = len(original)

    fig = plt.figure(figsize=(map_size - 0.3, 3))
    kwargs = {
        's'          : 2200,
        'c'          : '#c0392b',
        'marker'     : "s",
        'alpha'      : 0.5,
    }
    
    scale = 1.0
    
    # base
    kwargs['c'] = "#f19066"
    kwargs['marker'] = 's'
    n = [(b / scale, 0) for b in range(map_size + 1)]
    plt.scatter([x[0] for x in n], [x[1] for x in n], **kwargs)

    # sky
    kwargs['c'] = "#70a1ff"
    kwargs['marker'] = 's'
    plt.scatter([s[0] / scale for s in sky], [s[1] for s in sky], **kwargs)
    
    # goomba
    kwargs['c'] = "#57606f"
    kwargs['marker'] = 'X'
    n = [(g, goomba_y) for g in goomba]
    plt.scatter([x[0] / scale for x in n], [x[1] for x in n], **kwargs)
    
    # mushroom
    kwargs['c'] = "#218c74"
    kwargs['marker'] = 'P'
    n = [(m, mushroom_y) for m in mushroom]
    plt.scatter([x[0] / scale for x in n], [x[1] for x in n], **kwargs)
    
    # lakitu
    kwargs['c'] = "#ffa502"
    kwargs['marker'] = 'X'
    n = [(l, lakity_y) for l in lakitu]
    scat = plt.scatter([x[0] / scale for x in n], [x[1] for x in n], **kwargs)
    
    # luigi
    kwargs['c'] = "#ff3f34"
    kwargs['s'] = 1000
    if len(luigi) == 1:
        kwargs['marker'] = 's'
        scat = plt.scatter(luigi[0][0], luigi[0][1], **kwargs)
    else:
        kwargs['marker'] = 's'
        scat = plt.scatter(luigi[1][0], luigi[1][1], **kwargs)
        
        kwargs['marker'] = 's'
        scat = plt.scatter(luigi[0][0], luigi[0][1], **kwargs)
        
    # flag
    kwargs['s'] = 2000
    kwargs['c'] = "#1e272e"
    kwargs['marker'] = '|'
    kwargs['alpha'] = 1
    plt.scatter(map_size, ground_y, **kwargs)
    kwargs['marker'] = 8
    kwargs['alpha'] = 0.8
    plt.scatter(map_size, ground_y + 1, **kwargs)
    

    ax = scat.axes
#     ax.invert_yaxis()

    if show:
        plt.show()
    if save:
        from pathlib import Path
        if not path:
            path = "../default_export_path/"
        Path(path).mkdir(parents=True, exist_ok=True)
        fig.savefig(f'{path}{file_name}', dpi=dpi)
        plt.close(fig)

# loading map and showing it

inputs = [
    "../attachments/levels/level1.txt",
    "../attachments/levels/level2.txt",
    "../attachments/levels/level3.txt",
    "../attachments/levels/level4.txt",
    "../attachments/levels/level5.txt",
    "../attachments/levels/level6.txt",
    "../attachments/levels/level7.txt",
    "../attachments/levels/level8.txt",
    "../attachments/levels/level9.txt",
    "../attachments/levels/level10.txt",
]
main_configurations = [setup_map_config(f) for f in inputs]
for index,c in enumerate(main_configurations):
    print(f'config number {index + 1} --------------')
    draw_config(c, save=True, path="../output/map/", file_name=f"{index + 1}.png")
# Out:
# config number 1 --------------
# config number 2 --------------
# config number 3 --------------
# config number 4 --------------
# config number 5 --------------
# config number 6 --------------
# config number 7 --------------
# config number 8 --------------
# config number 9 --------------
# config number 10 --------------

# %%
def state_maker(seq):
    state = 's0'
    next_state = None
    
    states = [state]
    for index, s in enumerate(seq):
        if state == 's0':
            if s == '0': next_state = 's0'
            if s == '1': next_state = 's1'
            if s == '2': next_state = 's2'
        elif state == 's1':
            if s == '0': next_state = 's0'
            if s == '1': next_state = 's0'
            if s == '2': next_state = 's0'
        elif state == 's2':
            if s == '0': next_state = 's0'
            if s == '1': next_state = 's1'
            if s == '2': next_state = 's2'
        states.append(next_state)
        state = next_state
    return states

    
import pprint 
pprint.pprint(state_maker('0010020011111'))
# Out:
# ['s0',
#  's0',
#  's0',
#  's1',
#  's0',
#  's0',
#  's2',
#  's0',
#  's0',
#  's1',
#  's0',
#  's1',
#  's0',
#  's1']

# %%
import copy
def do_interactions(seq, config):
    mushroom = copy.deepcopy(config['mushroom'])
    result = []
    
    for index, s in enumerate(seq):
        luigi = []
        if s == 's0':
            luigi.append((index, ground_y))
            luigi.append((index, ground_y + 1))
            
            if index in mushroom:
                mushroom.remove(index)
            
        elif s == 's1':
            luigi.append((index, ground_y + 1))
            luigi.append((index, ground_y + 2))
            
        elif s == 's2':
            luigi.append((index, ground_y))
            
            if index in mushroom:
                mushroom.remove(index)
        
        result.append({
            'luigi': luigi,
            'mushroom' : copy.deepcopy(mushroom),
        })
#         result['luigi'].append(luigi)
#         result['mushroom'].append(copy.deepcopy(mushroom))
        
    return result

# %%
import pprint
pprint.pprint(do_interactions(state_maker('0000100002200100200100001'), main_configurations[6]))
# Out:
# [{'luigi': [(0, 1), (0, 2)], 'mushroom': [1, 3, 6, 22]},
#  {'luigi': [(1, 1), (1, 2)], 'mushroom': [3, 6, 22]},
#  {'luigi': [(2, 1), (2, 2)], 'mushroom': [3, 6, 22]},
#  {'luigi': [(3, 1), (3, 2)], 'mushroom': [6, 22]},
#  {'luigi': [(4, 1), (4, 2)], 'mushroom': [6, 22]},
#  {'luigi': [(5, 2), (5, 3)], 'mushroom': [6, 22]},
#  {'luigi': [(6, 1), (6, 2)], 'mushroom': [22]},
#  {'luigi': [(7, 1), (7, 2)], 'mushroom': [22]},
#  {'luigi': [(8, 1), (8, 2)], 'mushroom': [22]},
#  {'luigi': [(9, 1), (9, 2)], 'mushroom': [22]},
#  {'luigi': [(10, 1)], 'mushroom': [22]},
#  {'luigi': [(11, 1)], 'mushroom': [22]},
#  {'luigi': [(12, 1), (12, 2)], 'mushroom': [22]},
#  {'luigi': [(13, 1), (13, 2)], 'mushroom': [22]},
#  {'luigi': [(14, 2), (14, 3)], 'mushroom': [22]},
#  {'luigi': [(15, 1), (15, 2)], 'mushroom': [22]},
#  {'luigi': [(16, 1), (16, 2)], 'mushroom': [22]},
#  {'luigi': [(17, 1)], 'mushroom': [22]},
#  {'luigi': [(18, 1), (18, 2)], 'mushroom': [22]},
#  {'luigi': [(19, 1), (19, 2)], 'mushroom': [22]},
#  {'luigi': [(20, 2), (20, 3)], 'mushroom': [22]},
#  {'luigi': [(21, 1), (21, 2)], 'mushroom': [22]},
#  {'luigi': [(22, 1), (22, 2)], 'mushroom': []},
#  {'luigi': [(23, 1), (23, 2)], 'mushroom': []},
#  {'luigi': [(24, 1), (24, 2)], 'mushroom': []},
#  {'luigi': [(25, 2), (25, 3)], 'mushroom': []}]

# %%
pprint.pprint(main_configurations[6])
# Out:
# {'goomba': [5, 14, 20],
#  'ground': [0, 2, 4, 7, 8, 9, 12, 13, 15, 16, 18, 19, 21, 23, 24],
#  'lakitu': [10, 11, 17],
#  'luigi': [(0, 1), (0, 2)],
#  'mushroom': [1, 3, 6, 22],
#  'original': '_M_M_GM___LL__G__L__G_M__',
#  'sky': [(0, 1),
#          (0, 2),
#          (0, 3),
#          (1, 1),
#          (1, 2),
#          (1, 3),
#          (2, 1),
#          (2, 2),
#          (2, 3),
#          (3, 1),
#          (3, 2),
#          (3, 3),
#          (4, 1),
#          (4, 2),
#          (4, 3),
#          (5, 1),
#          (5, 2),
#          (5, 3),
#          (6, 1),
#          (6, 2),
#          (6, 3),
#          (7, 1),
#          (7, 2),
#          (7, 3),
#          (8, 1),
#          (8, 2),
#          (8, 3),
#          (9, 1),
#          (9, 2),
#          (9, 3),
#          (10, 1),
#          (10, 2),
#          (10, 3),
#          (11, 1),
#          (11, 2),
#          (11, 3),
#          (12, 1),
#          (12, 2),
#          (12, 3),
#          (13, 1),
#          (13, 2),
#          (13, 3),
#          (14, 1),
#          (14, 2),
#          (14, 3),
#          (15, 1),
#          (15, 2),
#          (15, 3),
#          (16, 1),
#          (16, 2),
#          (16, 3),
#          (17, 1),
#          (17, 2),
#          (17, 3),
#          (18, 1),
#          (18, 2),
#          (18, 3),
#          (19, 1),
#          (19, 2),
#          (19, 3),
#          (20, 1),
#          (20, 2),
#          (20, 3),
#          (21, 1),
#          (21, 2),
#          (21, 3),
#          (22, 1),
#          (22, 2),
#          (22, 3),
#          (23, 1),
#          (23, 2),
#          (23, 3),
#          (24, 1),
#          (24, 2),
#          (24, 3),
#          (25, 1),
#          (25, 2),
#          (25, 3)]}

# %%
import copy
solu = do_actions(state_maker('0000100002200100200100001'), main_configurations[6])
if solu:
    conf = copy.deepcopy(main_configurations[6])
    for idx,s in enumerate(solu):
        conf['luigi'] = s['luigi']
        conf['mushroom'] = s['mushroom']
        draw_config(conf)

# %%
[(i,0) & (7,i) for i, x in enumerate("hello whats up lolo ?") if x == 'l']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a22785dc1383> in <module>
# ----> 1 [(i,0) & (7,i) for i, x in enumerate("hello whats up lolo ?") if x == 'l']
#
# <ipython-input-8-a22785dc1383> in <listcomp>(.0)
# ----> 1 [(i,0) & (7,i) for i, x in enumerate("hello whats up lolo ?") if x == 'l']
#
# TypeError: unsupported operand type(s) for &: 'tuple' and 'tuple'
